# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook provides basic data checks for the Recipe Recommendation Dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/recipes_data.csv')
print(df.shape)
df.head()

# %%
df['Cuisine_Type'].value_counts().plot(kind='bar', title='Cuisine Counts')
plt.show()
